# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# url = "https://www.flipkart.com/search?q=mobiles+under+5000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"
# url = "https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes&query=Kenya&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-09-01&monthly_length=3&monthly_end_date=2025-12-01&search_mode=regular_search&price_filter_input_type=2&channel=EXPLORE&search_type=unknown&pagination_search=true&price_filter_num_nights=5&federated_search_session_id=3210909b-e9a5-4799-9b72-831f38a3e77d&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D"

# %%
# Find next page; page2
url = "https://www.jumia.co.ke/android-phones/"
r = requests.get(url)
print(r)
soup = BeautifulSoup(r.text, "html.parser")
# print(soup)
np = soup.find("a", {"aria-label":"Next Page"}).get("href")
cnp = "https://www.jumia.co.ke"+np
print(cnp)
# Out:
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing

# %%
# Find next page; page3
url = cnp
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
np = soup.find("a", {"aria-label":"Next Page"}).get("href")
page3 = "https://www.jumia.co.ke"+np
print(page3)
# Out:
# https://www.jumia.co.ke/android-phones/?page=3#catalog-listing

# %%
# Find next pages by iteration
for i in range(1, 11):
  url = "https://www.jumia.co.ke/android-phones/"
  r = requests.get(url)
  print(r)

  soup = BeautifulSoup(r.text, "html.parser")

  np = soup.find("a", {"aria-label":"Next Page"}).get("href")
  cnp = "https://www.jumia.co.ke"+np
  print(cnp)
# Out:
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing
# <Response [200]>
# https://www.jumia.co.ke/android-phones/?page=2#catalog-listing

# %% [markdown]
# ## Airbn data - Kenya

# %%
url = "https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes"
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# ...

# %%
np = soup.find("a", {"aria-label":"Next"}).get("href")
page = "https://www.airbnb.com"+np
print(page)
# Out:
# https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes&query=Kenya&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-09-01&monthly_length=3&monthly_end_date=2025-12-01&search_mode=regular_search&price_filter_input_type=2&channel=EXPLORE&federated_search_session_id=2b293d5b-2129-44a0-9e39-144a157dbe61&search_type=unknown&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D

# %%
url = "https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes"
r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "html.parser")

while True:
  np = soup.find("a", {"aria-label":"Next"}).get("href")
  page = "https://www.airbnb.com"+np
  print(page)

  url = page
  r = requests.get(url)
  soup = BeautifulSoup(r.text, "html.parser")
  np = soup.find("a", {"aria-label":"Next"}).get("href")
  page = "https://www.airbnb.com"+np
# Out:
# <Response [200]>
# https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes&query=Kenya&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-09-01&monthly_length=3&monthly_end_date=2025-12-01&search_mode=regular_search&price_filter_input_type=2&channel=EXPLORE&federated_search_session_id=1cdfab88-1439-4515-8318-c2d15fa00822&search_type=unknown&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D
# ...

# %%
# find elements

url = "https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes"
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, "html.parser")

location = []
name = []
price = []
rating = []


locations = soup.find_all("div", {"class":"t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_jt7fhx atm_cs_10d11i2 atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr"})
for i in locations:
  # print(i.text)
  location.append(i.text)
# print(location)
print(len(location))

names = soup.find_all("span", {"class":"t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_1he744i atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr"})
for i in names:
  # print(i.text)
  name.append(i.text)
print(len(name))

prices = soup.find_all("span", {"class": "umg93v9 atm_7l_rb934l atm_cs_1peztlj atm_rd_14k51in atm_cs_kyjlp1__1v156lz dir dir-ltr"})
for i in prices:
  # print(i.text)
  price.append(i.text)
print(len(price))

box = soup.find("div", {"class":"fwts1ay atm_gq_p5ox87 atm_h3_dlk8xv dir dir-ltr"})
box2 = box.find("div", {"class":"t1phmnpa atm_da_1ko3t4y atm_dm_kb7nvz atm_fg_h9n0ih dir dir-ltr"})
ratings = box2.find_all('span', {'aria-hidden': 'true'})
for i in ratings:
  # ratings = box2.find_all('span', {'aria-hidden': 'true'})
  # print(i.text) , "Rating":ratings , "Price":price "Location": location,"Name":name,
  rating.append(i.text)
print(len(rating))

df = pd.DataFrame({"Rating":rating})
df
# Out:
# 18
# 18
# 18
# 1
#        Rating
# 0  4.93 (121)

# %%
url = "https://www.airbnb.com/s/Kenya/homes?place_id=ChIJD5BQg9CAJxgR2W2XobAOO0A&refinement_paths%5B%5D=%2Fhomes"
r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "html.parser")

location = []
name = []
price = []
rating = []

for i in range(1,3):
  np = soup.find("a", {"aria-label":"Next"}).get("href")
  page = "https://www.airbnb.com"+np
  # print(page)

  url = page
  r = requests.get(url)
  soup = BeautifulSoup(r.text, "html.parser")
  np = soup.find("a", {"aria-label":"Next"}).get("href")
  page = "https://www.airbnb.com"+np


  locations = soup.find_all("div", {"class":"t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_jt7fhx atm_cs_10d11i2 atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr"})
  for i in locations:
    # print(i.text)
    location.append(i.text)
  # print(location)

  names = soup.find_all("span", {"class":"t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_1he744i atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr"})
  for i in names:
    # print(i.text)
    name.append(i.text)

  prices = soup.find_all("span", {"class": "umg93v9 atm_7l_rb934l atm_cs_1peztlj atm_rd_14k51in atm_cs_kyjlp1__1v156lz dir dir-ltr"})
  for i in prices:
    # print(i.text)
    price.append(i.text)

  box = soup.find_all("div", {"class":"t1phmnpa atm_da_1ko3t4y atm_dm_kb7nvz atm_fg_h9n0ih dir dir-ltr"})
  ratings = box.find('span', {'aria-hidden': 'true'})
  for i in ratings:
    # print(i.text)
    rating.append(i.text)
#df = pd.DataFrame({"Location": location,"Name":name, "Price":price, "Rating":ratings})
df = pd.DataFrame({"Location": location,"Name":name, "Rating":ratings})
df
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 41
#      38   price.append(i.text)
#      40 box = soup.find_all("div", {"class":"t1phmnpa atm_da_1ko3t4y atm_dm_kb7nvz atm_fg_h9n0ih dir dir-ltr"})
# ---> 41 ratings = box.find('span', {'aria-hidden': 'true'})
#      42 for i in ratings:
#      43   # print(i.text)
#      44   rating.append(i.text)
#
# File c:\Users\Sharon\Desktop\Data Mining\data-mining\Lib\site-packages\bs4\element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
# ...

# %%
box = soup.find_all("div", {"class":"t1phmnpa atm_da_1ko3t4y atm_dm_kb7nvz atm_fg_h9n0ih dir dir-ltr"})
ratings = box.find_all('span', {'aria-hidden': 'true'})
for i in ratings:
  print(i.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[121], line 2
#       1 box = soup.find_all("div", {"class":"t1phmnpa atm_da_1ko3t4y atm_dm_kb7nvz atm_fg_h9n0ih dir dir-ltr"})
# ----> 2 ratings = box.find_all('span', {'aria-hidden': 'true'})
#       3 for i in ratings:
#       4   print(i.text)
#
# File c:\Users\Sharon\Desktop\Data Mining\data-mining\Lib\site-packages\bs4\element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
#
# ...
